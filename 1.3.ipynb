# %%
import platform
import datetime
import socket
import os

# %%
# 当前时间
now = datetime.datetime.now()

# 系统信息
system = platform.system()
system_version = platform.version()

# 电脑名称
hostname = socket.gethostname()

# CPU信息
cpu = platform.processor()

# Python版本
python_version = platform.python_version()

# IP
hostname = socket.gethostname()
ip = socket.gethostbyname(hostname)

# %%
print("====== 电脑信息 ======")
print("电脑名称:", hostname)
print("姓名:", "陶量")
print("Python版本:", python_version)
print("学号:", "2024 1017 9018")
print("IP地址:", ip)
print("\n====== 当前时间 ======")
print("时间:", now.strftime("%Y-%m-%d %H:%M:%S"))

os.system("cls")
print("\r")
# Out:
# ====== 电脑信息 ======
# 电脑名称: tl
# 姓名: 陶量
# Python版本: 3.10.19
# 学号: 2024 1017 9018
# IP地址: 172.20.10.10
#
# ====== 当前时间 ======
# 时间: 2026-03-11 16:18:41
